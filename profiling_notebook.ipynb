# %%
from clifftrace import *

# %%
# %%prun -s cumulative
render_image()
# Out:
# DrawLine((1.0^e245),rgb(255, 0 , 0));
# DrawLine((0.70711^e245) - (0.70711^e345),rgb(255, 0 , 0));
# DrawEucPoint(-(6.0^e2) + (6.0^e3) + (35.5^e4) + (36.5^e5),rgb(0, 0, 255));
# DrawEucPoint(-(0.5^e4) + (0.5^e5),rgb(0, 0, 255));
# DrawEucPoint(-(1.0^e1) - (4.76256^e2) + (5.82322^e3) + (28.29597^e4) + (29.29597^e5),rgb(0,255,255));
# DrawEucPoint((1.0^e1) - (4.76256^e2) + (5.82322^e3) + (28.29597^e4) + (29.29597^e5),rgb(0,255,255));
# DrawEucPoint((1.0^e1) - (5.82322^e2) + (4.76256^e3) + (28.29597^e4) + (29.29597^e5),rgb(0,255,255));
# DrawEucPoint(-(1.0^e1) - (5.82322^e2) + (4.76256^e3) + (28.29597^e4) + (29.29597^e5),rgb(0,255,255));
# DrawPointPair((4.76256^e12) - (5.82322^e13) - (28.29597^e14) - (29.29597^e15),rgb(8, 0, 84));
# DrawPointPair(-(0.94281^e12) - (0.94281^e13) + (9.98038^e23) + (26.6777^e24) + (27.6205^e25) + (26.6777^e34) + (27.6205^e35),rgb(8, 0, 84));
# DrawPointPair(-(5.82322^e12) + (4.76256^e13) + (28.29597^e14) + (29.29597^e15),rgb(8, 0, 84));
# ...
